# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import numpy as np 
import scipy.fft
from operators import solve_poisson_equation, psi_ln_sw, solve_poisson_equation_two_stream, fft_, density_convolve, linear_2_two_stream

# %%
import matplotlib.pyplot as plt
from mycolorpy import colorlist as mcp
import matplotlib.pylab as pl
import matplotlib
font = {'family' : 'serif',
        'size'   : 12}

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12)

# %% [markdown]
# # Two stream

# %%
# set up configuration parameters
# number of mesh points in x
Nx = 20
# number of spectral expansions
Nv = 10
# Velocity scaling of electron and ion
alpha_e1 = 0.5
alpha_e2 = 0.5
alpha_i = np.sqrt(2 / 1863)
# perturbation magnitude
epsilon = 1e-2
# x grid is from 0 to L
L = 2 * np.pi
# final time
T = 60.
# time stepping
dt = 0.1
# time vector
t_vec = np.linspace(0, T, int(T / dt) + 1)
# velocity scaling
u_e1 = -1
u_e2 = 1
u_i = 0
# mass normalized
m_e1 = 1
m_e2 = 1
m_i = 1863
# charge normalized
q_e1 = -1
q_e2 = -1
q_i = 1
# scaling of bulk and bump
delta_e1 = 0.5
delta_e2 = 0.5

# %%
# velocity grid for plotting purposes
v = np.linspace(-3, 3, int(1e3))
# spatial grid 
x_project = np.linspace(0, L, int(1e5))
x = np.linspace(0, L, 2*Nx+1)

# %%
# initial condition of the first expansion coefficient
C_0i = np.zeros(2 * Nx + 1)
C_0i[Nx] = np.sqrt(1 / alpha_i)

# %%
# initial condition of the first expansion coefficient
C_0e1 = np.zeros(2 * Nx + 1, dtype="complex128")
C_0e2 = np.zeros(2 * Nx + 1, dtype="complex128")

# project the electron species onto fourier space
for ii, kk in enumerate(range(-Nx, Nx + 1)):
    C_0e1[ii] = np.trapz(y=np.sqrt(delta_e1 * (1 + epsilon * np.cos(x_project)) / alpha_e1) * np.exp(-2 * np.pi * 1j * kk *  x_project / L),
                         x=x_project,
                         dx= x_project[1] -  x_project[0]) / L
    C_0e2[ii] = np.trapz(y=np.sqrt(delta_e2 * (1 + epsilon * np.cos(x_project)) / alpha_e2) * np.exp(-2 * np.pi * 1j * kk *  x_project / L),
                         x= x_project,
                         dx= x_project[1] -  x_project[0]) / L

# %%
# initialize states (electrons and ions)
states_e1 = np.zeros((Nv, Nx * 2 + 1), dtype="complex128")
states_e2 = np.zeros((Nv, Nx * 2 + 1), dtype="complex128")
states_i = np.zeros((Nv, Nx * 2 + 1), dtype="complex128")

# initialize the expansion coefficients
states_e1[0, :] = C_0e1
states_e2[0, :] = C_0e2
states_i[0, :] = C_0i

# %%
E_coeff = solve_poisson_equation_two_stream(state_e1=states_e1,
                                            state_e2=states_e2,
                                            state_i=states_i,
                                            alpha_e1=alpha_e1,
                                            alpha_e2=alpha_e2,
                                            alpha_i=alpha_i,
                                            Nx=Nx,
                                            L=L, u_e1=u_e1, u_e2=u_e2, u_i=u_i, Nv=Nv)
# Out:
# charge neutrality =  1.1102230246251565e-16

# %%
# the distribution function of electrons and protons for plotting purposes
f_0e1 = np.outer(fft_(C_0e1, Nx, x, L), psi_ln_sw((v-u_e1)/alpha_e1, n=0)).real
f_0e2 = np.outer(fft_(C_0e2, Nx, x, L), psi_ln_sw((v-u_e2)/alpha_e2, n=0)).real
f_0i = np.outer(fft_(C_0i, Nx, x, L), psi_ln_sw((v-u_i)/alpha_i, n=0)).real

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 3))
pos = ax[0].pcolormesh(x, v, (f_0e1**2 + f_0e2**2).T, cmap="inferno")
ax[0].set_xlabel("x")
ax[0].set_ylabel("v")
cbar = fig.colorbar(pos)

cbar.ax.set_ylabel('$f^{e}(x, v, t=0)$', rotation=90)
ax[0].set_title("$f^{e}(x, v, t=0)$")

pos = ax[1].pcolormesh(x, v, (f_0i**2).T, cmap="inferno")
ax[1].set_ylim(-0.1, 0.1)
ax[1].set_yticks([-0.1, 0, 0.1])
ax[1].set_ylabel("v")
ax[1].set_xlabel("x")
cbar = fig.colorbar(pos)
cbar.ax.set_ylabel('$f^{i}(x, v, t=0)$', rotation=90)
ax[1].set_title("$f^{i}(x, v, t=0)$")
plt.tight_layout()
plt.savefig("figs/SW_sqrt/bump_on_tail/poisson/initial_condition_bump_on_tail.png", dpi=600)

# %%
sol_midpoint_u = np.load("data/SW_sqrt/two_stream/poisson/sol_midpoint_u_10.npy")
sol_midpoint_t = np.load("data/SW_sqrt/two_stream/poisson/sol_midpoint_t_10.npy")
print(np.shape(sol_midpoint_u))
print(np.shape(sol_midpoint_t))
# Out:
# (820, 601)
# (601,)

# %%
# initialize the electric potential
E_midpoint = np.zeros((2*Nx+1, len(sol_midpoint_t)), dtype="complex128")

# %%
# initialize the states for implicit midpoint (symplectic)
state_e1_midpoint = np.zeros((Nv, 2*Nx+1, len(sol_midpoint_t)), dtype="complex128")
state_e2_midpoint = np.zeros((Nv, 2*Nx+1, len(sol_midpoint_t)), dtype="complex128")
state_i_midpoint = np.zeros((Nv, 2*Nx+1, len(sol_midpoint_t)), dtype="complex128")


for ii in range(len(sol_midpoint_t)):
    for jj in range(Nv):
        # unwind the flattening in order to solve the linear system
        state_e1_midpoint[jj, :, ii] = sol_midpoint_u[jj * (2 * Nx + 1): (jj + 1) * (2 * Nx + 1), ii]
        state_e2_midpoint[jj, :, ii] = sol_midpoint_u[Nv*(2 * Nx + 1) + jj * (2 * Nx + 1): Nv*(2 * Nx + 1) + (jj + 1) * (2 * Nx + 1), ii]
        state_i_midpoint[0, Nx, ii] = np.sqrt(1 / alpha_i)
        
    E_midpoint[:, ii] = solve_poisson_equation_two_stream(state_e1=state_e1_midpoint[:, :, ii],
                                                          state_e2=state_e2_midpoint[:, :, ii],
                                                          state_i=state_i_midpoint[:, :, ii],
                                                          alpha_e1=alpha_e1,
                                                          alpha_e2=alpha_e2,
                                                          alpha_i=alpha_i,
                                                          Nx=Nx, Nv=Nv,
                                                          L=L, u_e1=u_e1, u_e2=u_e2, u_i=u_i, solver="SWSR")
# Out:
# charge neutrality =  0.0
# charge neutrality =  0.0
# charge neutrality =  3.3306690738754696e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  0.0
# charge neutrality =  0.0
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  3.3306690738754696e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  5.551115123125783e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  7.771561172376096e-16
# charge neutrality =  7.771561172376096e-16
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  9.992007221626409e-16
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.2212453270876722e-15
# charge neutrality =  1.2212453270876722e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.3322676295501878e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.887379141862766e-15
# charge neutrality =  1.9984014443252818e-15
# charge neutrality =  2.220446049250313e-15
# charge neutrality =  2.220446049250313e-15
# charge neutrality =  1.9984014443252818e-15
# charge neutrality =  1.9984014443252818e-15
# charge neutrality =  1.9984014443252818e-15
# charge neutrality =  2.4424906541753444e-15
# charge neutrality =  2.55351295663786e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.4424906541753444e-15
# charge neutrality =  2.1094237467877974e-15
# charge neutrality =  2.220446049250313e-15
# charge neutrality =  2.3314683517128287e-15
# charge neutrality =  2.4424906541753444e-15
# charge neutrality =  2.3314683517128287e-15
# charge neutrality =  1.887379141862766e-15
# charge neutrality =  2.3314683517128287e-15
# charge neutrality =  1.7763568394002505e-15
# charge neutrality =  1.6653345369377348e-15
# charge neutrality =  2.1094237467877974e-15
# charge neutrality =  1.9984014443252818e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.887379141862766e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.7763568394002505e-15
# charge neutrality =  1.887379141862766e-15
# charge neutrality =  1.3322676295501878e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  7.771561172376096e-16
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  9.992007221626409e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  1.3322676295501878e-15
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  0.0
# charge neutrality =  0.0
# charge neutrality =  0.0
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  5.551115123125783e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  0.0
# charge neutrality =  0.0
# charge neutrality =  -4.440892098500626e-16
# charge neutrality =  0.0
# charge neutrality =  -4.440892098500626e-16
# charge neutrality =  0.0
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  0.0
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  0.0
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  0.0
# charge neutrality =  -2.220446049250313e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  2.220446049250313e-16
# charge neutrality =  3.3306690738754696e-16
# charge neutrality =  3.3306690738754696e-16
# charge neutrality =  5.551115123125783e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  5.551115123125783e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  7.771561172376096e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  5.551115123125783e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.2212453270876722e-15
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  0.0
# charge neutrality =  0.0
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  5.551115123125783e-16
# charge neutrality =  3.3306690738754696e-16
# charge neutrality =  5.551115123125783e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  1.2212453270876722e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.2212453270876722e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.3322676295501878e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.3322676295501878e-15
# charge neutrality =  1.2212453270876722e-15
# charge neutrality =  1.3322676295501878e-15
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  1.7763568394002505e-15
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  6.661338147750939e-16
# charge neutrality =  1.1102230246251565e-15
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  1.1102230246251565e-16
# charge neutrality =  8.881784197001252e-16
# charge neutrality =  4.440892098500626e-16
# charge neutrality =  1.3322676295501878e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.5543122344752192e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.6653345369377348e-15
# charge neutrality =  1.4432899320127035e-15
# charge neutrality =  1.887379141862766e-15
# charge neutrality =  1.9984014443252818e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.886579864025407e-15
# charge neutrality =  2.886579864025407e-15
# charge neutrality =  2.7755575615628914e-15
# charge neutrality =  2.886579864025407e-15
# charge neutrality =  2.886579864025407e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.7755575615628914e-15
# charge neutrality =  2.6645352591003757e-15
# charge neutrality =  2.9976021664879227e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.107825191113079e-15
# charge neutrality =  4.6629367034256575e-15
# charge neutrality =  4.773959005888173e-15
# charge neutrality =  4.6629367034256575e-15
# charge neutrality =  5.551115123125783e-15
# charge neutrality =  6.106226635438361e-15
# charge neutrality =  7.105427357601002e-15
# charge neutrality =  6.772360450213455e-15
# charge neutrality =  6.439293542825908e-15
# charge neutrality =  6.217248937900877e-15
# charge neutrality =  6.661338147750939e-15
# charge neutrality =  6.8833827526759706e-15
# charge neutrality =  6.106226635438361e-15
# charge neutrality =  4.551914400963142e-15
# charge neutrality =  4.6629367034256575e-15
# charge neutrality =  5.662137425588298e-15
# charge neutrality =  5.551115123125783e-15
# charge neutrality =  5.551115123125783e-15
# charge neutrality =  4.440892098500626e-15
# charge neutrality =  4.9960036108132044e-15
# charge neutrality =  4.884981308350689e-15
# charge neutrality =  3.885780586188048e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  2.886579864025407e-15
# charge neutrality =  3.1086244689504383e-15
# charge neutrality =  1.7763568394002505e-15
# charge neutrality =  1.9984014443252818e-15
# charge neutrality =  3.3306690738754696e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.107825191113079e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.885780586188048e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.885780586188048e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.552713678800501e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.3306690738754696e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.552713678800501e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.885780586188048e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.552713678800501e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.885780586188048e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.6637359812630166e-15
# charge neutrality =  3.552713678800501e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  3.885780586188048e-15
# charge neutrality =  3.774758283725532e-15
# charge neutrality =  4.107825191113079e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.107825191113079e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  3.9968028886505635e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.3298697960381105e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.218847493575595e-15
# charge neutrality =  4.3298697960381105e-15
# charge neutrality =  4.440892098500626e-15
# charge neutrality =  4.3298697960381105e-15
# charge neutrality =  4.3298697960381105e-15
# charge neutrality =  4.440892098500626e-15
# charge neutrality =  4.6629367034256575e-15
# charge neutrality =  4.6629367034256575e-15
# charge neutrality =  4.6629367034256575e-15
# charge neutrality =  4.884981308350689e-15
# charge neutrality =  4.6629367034256575e-15
# charge neutrality =  4.773959005888173e-15
# charge neutrality =  4.884981308350689e-15
# charge neutrality =  4.884981308350689e-15
# charge neutrality =  4.884981308350689e-15
# charge neutrality =  4.9960036108132044e-15
# charge neutrality =  5.218048215738236e-15
# charge neutrality =  5.10702591327572e-15
# charge neutrality =  4.884981308350689e-15
# charge neutrality =  5.10702591327572e-15
# charge neutrality =  5.329070518200751e-15
# charge neutrality =  5.329070518200751e-15
# charge neutrality =  5.329070518200751e-15
# charge neutrality =  5.329070518200751e-15
# charge neutrality =  5.329070518200751e-15
# charge neutrality =  5.329070518200751e-15
# charge neutrality =  5.551115123125783e-15
# charge neutrality =  5.551115123125783e-15
# charge neutrality =  5.551115123125783e-15
# charge neutrality =  5.773159728050814e-15
# charge neutrality =  5.773159728050814e-15
# charge neutrality =  5.773159728050814e-15
# charge neutrality =  5.662137425588298e-15
# charge neutrality =  5.88418203051333e-15
# charge neutrality =  5.88418203051333e-15
# charge neutrality =  5.995204332975845e-15
# charge neutrality =  5.995204332975845e-15
# charge neutrality =  6.217248937900877e-15
# charge neutrality =  5.995204332975845e-15
# charge neutrality =  6.217248937900877e-15
# charge neutrality =  6.106226635438361e-15
# charge neutrality =  6.217248937900877e-15
# charge neutrality =  6.5503158452884236e-15
# charge neutrality =  6.661338147750939e-15
# charge neutrality =  6.661338147750939e-15
# charge neutrality =  6.661338147750939e-15
# charge neutrality =  6.8833827526759706e-15
# charge neutrality =  6.772360450213455e-15
# charge neutrality =  6.772360450213455e-15
# charge neutrality =  6.8833827526759706e-15
# charge neutrality =  7.105427357601002e-15
# charge neutrality =  7.216449660063518e-15
# charge neutrality =  7.327471962526033e-15
# charge neutrality =  7.327471962526033e-15
# charge neutrality =  7.438494264988549e-15
# charge neutrality =  7.438494264988549e-15
# charge neutrality =  7.771561172376096e-15
# charge neutrality =  7.771561172376096e-15
# charge neutrality =  7.882583474838611e-15
# charge neutrality =  7.771561172376096e-15
# charge neutrality =  7.882583474838611e-15
# charge neutrality =  7.993605777301127e-15
# charge neutrality =  8.104628079763643e-15
# charge neutrality =  8.215650382226158e-15
# charge neutrality =  8.215650382226158e-15
# charge neutrality =  8.548717289613705e-15
# charge neutrality =  8.43769498715119e-15
# charge neutrality =  8.43769498715119e-15
# charge neutrality =  8.659739592076221e-15
# charge neutrality =  8.881784197001252e-15
# charge neutrality =  8.770761894538737e-15
# charge neutrality =  8.659739592076221e-15
# charge neutrality =  8.992806499463768e-15
# charge neutrality =  8.881784197001252e-15
# charge neutrality =  9.325873406851315e-15
# charge neutrality =  9.325873406851315e-15
# charge neutrality =  9.325873406851315e-15
# charge neutrality =  9.325873406851315e-15
# charge neutrality =  9.547918011776346e-15
# charge neutrality =  9.658940314238862e-15
# charge neutrality =  9.769962616701378e-15
# charge neutrality =  1.0103029524088925e-14
# charge neutrality =  9.992007221626409e-15
# charge neutrality =  1.021405182655144e-14
# charge neutrality =  1.021405182655144e-14
# charge neutrality =  1.0436096431476471e-14
# charge neutrality =  1.0436096431476471e-14
# charge neutrality =  1.0658141036401503e-14
# charge neutrality =  1.0658141036401503e-14
# charge neutrality =  1.0658141036401503e-14
# charge neutrality =  1.0880185641326534e-14
# charge neutrality =  1.1102230246251565e-14
# charge neutrality =  1.1324274851176597e-14
# charge neutrality =  1.1324274851176597e-14
# charge neutrality =  1.1324274851176597e-14
# charge neutrality =  1.1435297153639112e-14
# charge neutrality =  1.1546319456101628e-14
# charge neutrality =  1.1546319456101628e-14
# charge neutrality =  1.1546319456101628e-14
# charge neutrality =  1.1546319456101628e-14
# charge neutrality =  1.176836406102666e-14
# charge neutrality =  1.176836406102666e-14
# charge neutrality =  1.1879386363489175e-14
# charge neutrality =  1.176836406102666e-14
# charge neutrality =  1.1879386363489175e-14
# charge neutrality =  1.199040866595169e-14
# charge neutrality =  1.199040866595169e-14
# charge neutrality =  1.199040866595169e-14
# charge neutrality =  1.199040866595169e-14
# charge neutrality =  1.199040866595169e-14
# charge neutrality =  1.2212453270876722e-14
# charge neutrality =  1.2323475573339238e-14
# charge neutrality =  1.2323475573339238e-14
# charge neutrality =  1.2434497875801753e-14
# charge neutrality =  1.2434497875801753e-14
# charge neutrality =  1.2434497875801753e-14
# charge neutrality =  1.2656542480726785e-14
# charge neutrality =  1.2545520178264269e-14
# charge neutrality =  1.2878587085651816e-14
# charge neutrality =  1.2656542480726785e-14
# charge neutrality =  1.27675647831893e-14
# charge neutrality =  1.2878587085651816e-14
# charge neutrality =  1.2989609388114332e-14
# charge neutrality =  1.3100631690576847e-14
# charge neutrality =  1.3322676295501878e-14
# charge neutrality =  1.3100631690576847e-14
# charge neutrality =  1.3211653993039363e-14
# charge neutrality =  1.354472090042691e-14
# charge neutrality =  1.354472090042691e-14
# charge neutrality =  1.3655743202889425e-14
# charge neutrality =  1.3766765505351941e-14
# charge neutrality =  1.3766765505351941e-14
# charge neutrality =  1.3877787807814457e-14
# charge neutrality =  1.3988810110276972e-14
# charge neutrality =  1.3988810110276972e-14
# charge neutrality =  1.4210854715202004e-14
# charge neutrality =  1.4432899320127035e-14
# charge neutrality =  1.432187701766452e-14
# charge neutrality =  1.432187701766452e-14
# charge neutrality =  1.454392162258955e-14
# charge neutrality =  1.4654943925052066e-14
# charge neutrality =  1.4765966227514582e-14
# charge neutrality =  1.4988010832439613e-14
# charge neutrality =  1.4876988529977098e-14
# charge neutrality =  1.532107773982716e-14
# charge neutrality =  1.5210055437364645e-14
# charge neutrality =  1.532107773982716e-14
# charge neutrality =  1.5432100042289676e-14
# charge neutrality =  1.5765166949677223e-14
# charge neutrality =  1.5654144647214707e-14
# charge neutrality =  1.5765166949677223e-14
# charge neutrality =  1.5987211554602254e-14
# charge neutrality =  1.6209256159527285e-14
# charge neutrality =  1.6209256159527285e-14
# charge neutrality =  1.6209256159527285e-14
# charge neutrality =  1.6209256159527285e-14
# charge neutrality =  1.609823385706477e-14
# charge neutrality =  1.63202784619898e-14
# charge neutrality =  1.63202784619898e-14
# charge neutrality =  1.6431300764452317e-14
# charge neutrality =  1.6431300764452317e-14
# charge neutrality =  1.6653345369377348e-14
# charge neutrality =  1.6542323066914832e-14
# charge neutrality =  1.6431300764452317e-14
# charge neutrality =  1.6653345369377348e-14
# charge neutrality =  1.687538997430238e-14
# charge neutrality =  1.6764367671839864e-14
# charge neutrality =  1.687538997430238e-14
# charge neutrality =  1.687538997430238e-14
# charge neutrality =  1.6986412276764895e-14
# charge neutrality =  1.687538997430238e-14
# charge neutrality =  1.709743457922741e-14
# charge neutrality =  1.7319479184152442e-14
# charge neutrality =  1.7319479184152442e-14
# charge neutrality =  1.7319479184152442e-14
# charge neutrality =  1.7319479184152442e-14
# charge neutrality =  1.7430501486614958e-14
# charge neutrality =  1.7319479184152442e-14
# charge neutrality =  1.7319479184152442e-14
# charge neutrality =  1.7541523789077473e-14
# charge neutrality =  1.7763568394002505e-14
# charge neutrality =  1.7763568394002505e-14
# charge neutrality =  1.7763568394002505e-14
# charge neutrality =  1.7985612998927536e-14
# charge neutrality =  1.8207657603852567e-14
# charge neutrality =  1.84297022087776e-14
# charge neutrality =  1.84297022087776e-14
# charge neutrality =  1.865174681370263e-14
# charge neutrality =  1.887379141862766e-14
# charge neutrality =  1.887379141862766e-14
# charge neutrality =  1.887379141862766e-14
# charge neutrality =  1.887379141862766e-14
# charge neutrality =  1.9095836023552692e-14
# charge neutrality =  1.9095836023552692e-14
# charge neutrality =  1.9317880628477724e-14
# charge neutrality =  1.9317880628477724e-14
# charge neutrality =  1.942890293094024e-14
# charge neutrality =  1.965094753586527e-14
# charge neutrality =  1.9761969838327786e-14
# charge neutrality =  1.9984014443252818e-14
# charge neutrality =  1.9984014443252818e-14
# charge neutrality =  2.020605904817785e-14
# charge neutrality =  2.0317081350640365e-14
# charge neutrality =  2.042810365310288e-14
# charge neutrality =  2.0539125955565396e-14
# charge neutrality =  2.0650148258027912e-14
# charge neutrality =  2.0872192862952943e-14
# charge neutrality =  2.1094237467877974e-14
# charge neutrality =  2.1094237467877974e-14
# charge neutrality =  2.1316282072803006e-14
# charge neutrality =  2.1538326677728037e-14
# charge neutrality =  2.1760371282653068e-14
# charge neutrality =  2.19824158875781e-14
# charge neutrality =  2.2093438190040615e-14
# charge neutrality =  2.2426505097428162e-14
# charge neutrality =  2.2648549702353193e-14
# charge neutrality =  2.298161660974074e-14
# charge neutrality =  2.3314683517128287e-14
# charge neutrality =  2.353672812205332e-14
# charge neutrality =  2.398081733190338e-14
# charge neutrality =  2.4424906541753444e-14
# charge neutrality =  2.4646951146678475e-14
# charge neutrality =  2.4646951146678475e-14
# charge neutrality =  2.5091040356528538e-14
# charge neutrality =  2.5202062658991053e-14
# charge neutrality =  2.5646151868841116e-14
# charge neutrality =  2.5979218776228663e-14
# charge neutrality =  2.631228568361621e-14
# charge neutrality =  2.6423307986078726e-14
# charge neutrality =  2.6867397195928788e-14
# charge neutrality =  2.7200464103316335e-14
# charge neutrality =  2.731148640577885e-14
# charge neutrality =  2.7755575615628914e-14
# charge neutrality =  2.7977620220553945e-14
# charge neutrality =  2.8199664825478976e-14
# charge neutrality =  2.864375403532904e-14
# charge neutrality =  2.886579864025407e-14
# charge neutrality =  2.919886554764162e-14
# charge neutrality =  2.930988785010413e-14
# charge neutrality =  2.9531932455029164e-14
# charge neutrality =  2.9976021664879227e-14
# charge neutrality =  3.019806626980426e-14
# charge neutrality =  3.086420008457935e-14
# charge neutrality =  3.11972669919669e-14
# charge neutrality =  3.1308289294429414e-14
# charge neutrality =  3.197442310920451e-14
# charge neutrality =  3.2307490016592055e-14
# charge neutrality =  3.2862601528904634e-14
# charge neutrality =  3.3306690738754696e-14
# charge neutrality =  3.397282455352979e-14
# charge neutrality =  3.441691376337985e-14
# charge neutrality =  3.4861002973229915e-14
# charge neutrality =  3.5416114485542494e-14
# charge neutrality =  3.5860203695392556e-14
# charge neutrality =  3.6193270602780103e-14
# charge neutrality =  3.6637359812630166e-14
# charge neutrality =  3.708144902248023e-14
# charge neutrality =  3.752553823233029e-14
# charge neutrality =  3.7969627442180354e-14
# charge neutrality =  3.852473895449293e-14
# charge neutrality =  3.885780586188048e-14
# charge neutrality =  3.930189507173054e-14
# charge neutrality =  3.941291737419306e-14
# charge neutrality =  3.9745984281580604e-14
# charge neutrality =  3.9968028886505635e-14
# charge neutrality =  4.04121180963557e-14
# charge neutrality =  4.0523140398818214e-14
# charge neutrality =  4.063416270128073e-14
# charge neutrality =  4.107825191113079e-14
# charge neutrality =  4.107825191113079e-14
# charge neutrality =  4.141131881851834e-14
# charge neutrality =  4.1522341120980855e-14
# charge neutrality =  4.196643033083092e-14
# charge neutrality =  4.18554080283684e-14
# charge neutrality =  4.196643033083092e-14
# charge neutrality =  4.196643033083092e-14
# charge neutrality =  4.218847493575595e-14
# charge neutrality =  4.241051954068098e-14
# charge neutrality =  4.2521541843143495e-14
# charge neutrality =  4.285460875053104e-14
# charge neutrality =  4.285460875053104e-14
# charge neutrality =  4.285460875053104e-14
# charge neutrality =  4.3298697960381105e-14
# charge neutrality =  4.3520742565306136e-14
# charge neutrality =  4.374278717023117e-14
# charge neutrality =  4.39648317751562e-14

# %%
E_field = np.zeros(np.shape(E_midpoint))
for ii in range(len(sol_midpoint_t)):
    E_field[:, ii] = fft_(E_midpoint[:, ii], Nx, x, L)

# %%
print(E_midpoint[Nx -1, 0])
print(E_midpoint[Nx + 1, 0])
# Out:
# (9.240568373080236e-17-0.004999999999999935j)
# (9.240568373080236e-17+0.004999999999999935j)

# %%
fig, ax = plt.subplots(figsize=(7, 3))
pos = ax.contourf(x, sol_midpoint_t, E_field.T, cmap="RdBu")
cbar = fig.colorbar(pos)
cbar.ax.set_ylabel("$E(x, t)$", rotation=90)
ax.set_title("$E(x, t)$")
ax.set_xlabel("$x$")
_ = ax.set_xticks([0, np.pi, 2*np.pi-.05])
_ = ax.set_xticklabels([r"0", r"$\pi$", r"$2\pi$"])
_ = ax.set_ylabel("$t$")
plt.tight_layout()

plt.savefig("figs/SW_sqrt/bump_on_tail/poisson/electric_field_SW_sqrt.png", dpi=600)

# %%
E1_midpoint = np.zeros(len(sol_midpoint_t))


for ii in range(len(sol_midpoint_t)):
    E1_midpoint[ii] = np.abs(E_midpoint[Nx+1, ii])

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(sol_midpoint_t, E1_midpoint, "-", c="purple", alpha=0.5, linewidth=3, label="SW square-root") 
#ax.plot(sol_midpoint_t, np.exp(-0.851*sol_midpoint_t)*1e-2, linewidth=3, color="red", label=r"theory $\gamma = -0.851$") 

ax.set_yscale("log")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_ylabel("$|\hat{E}(1)|$")
ax.set_xlabel("$ t$")
ax.set_xlim(0, T)
legend = ax.legend(ncols=1, fancybox=False, shadow=False, fontsize=12, loc='upper right')
legend.get_frame().set_alpha(0)
plt.tight_layout()
plt.savefig("figs/SW_sqrt/linear_landau/poisson/damping_rate_electric_field.png", dpi=600)

# %%
fig, ax = plt.subplots(nrows=5, sharex=True, figsize=(5, 10))
for tt, ii in enumerate(range(0, len(sol_midpoint_t), int(len(sol_midpoint_t)//4))):
    distribution1 = np.zeros((2*Nx+1, len(v)))
    distribution2 = np.zeros((2*Nx+1, len(v)))
    for jj in range(Nv):
        distribution1 += np.outer(fft_(state_e1_midpoint[jj, :, ii], Nx, x, L), psi_ln_sw((v-u_e1)/alpha_e1, n=jj)).real
        distribution2 += np.outer(fft_(state_e2_midpoint[jj, :, ii], Nx, x, L), psi_ln_sw((v-u_e2)/alpha_e2, n=jj)).real
        
    levels = np.append(-0.1, np.linspace(0, 0.4, 15))
    colors = mcp.gen_color(cmap="inferno",n=len(levels)-1)
    pos = ax[tt].contourf(x, v, (distribution1**2 + distribution2**2).T, levels=levels, colors=np.append(["w"], colors))
    #ax[tt].set_xticks([0, 5*np.pi, 10*np.pi, 15*np.pi, 20*np.pi])
    #ax[tt].set_xticklabels([r"0", r"$5\pi$", r"$10\pi$", r"$15\pi$", r"$20\pi$"])
    ax[tt].set_ylabel("v")
    cbar = fig.colorbar(pos)
    cbar.ax.set_yticks([0, 0.2, 0.4])
    ax[tt].set_title("$f^{e}(x, v, t=$" + str(int(sol_midpoint_t[ii])) + ")", fontsize=12)
ax[-1].set_xlabel("x")
plt.tight_layout()
plt.savefig("figs/SW_sqrt/bump_on_tail/poisson/bump_on_tail_evolution_SW_sqrt.png", dpi=600)

# %%
fig, ax = plt.subplots(figsize=(6, 3))

ii = -1

distribution1 = np.zeros((2*Nx+1, len(v)))
distribution2 = np.zeros((2*Nx+1, len(v)))

for jj in range(Nv):
    distribution1 +=  np.outer(fft_(state_e1_midpoint[jj, :, ii], Nx, x, L), psi_ln_sw((v-u_e1)/alpha_e1, n=jj)).real
    distribution2 +=  np.outer(fft_(state_e2_midpoint[jj, :, ii], Nx, x, L), psi_ln_sw((v-u_e2)/alpha_e2, n=jj)).real
    
levels = np.append(-0.1, np.linspace(0, 0.4, 15))
colors = mcp.gen_color(cmap="inferno",n=len(levels)-1)
pos = ax.contourf(x, v, (distribution1**2 + distribution2**2).T, levels=levels, colors=np.append(["w"], colors))
ax.set_xlabel("x")
ax.set_ylabel("v")
cbar = fig.colorbar(pos)
cbar.ax.set_ylabel('$f^{e}(x, v, t=$' + str(int(sol_midpoint_t[ii])) + ")", rotation=90)
cbar.ax.set_yticks([0, 0.1, 0.2, 0.3])
plt.tight_layout()
plt.savefig("figs/SW_sqrt/bump_on_tail/poisson/bump_on_tail_electron_distribution_t_20_SW_sqrt.png", dpi=600)

# %%
rho = np.zeros((2*Nx+1, len(sol_midpoint_t)), dtype="complex128")
               
for ii in range(len(sol_midpoint_t)):
    rho[:, ii]  = linear_2_two_stream(state_e1=state_e1_midpoint[:, :, ii], 
                                      state_e2=state_e2_midpoint[:, :, ii], 
                                      state_i=state_i_midpoint[:, :, ii], 
                                      alpha_e1=alpha_e1,
                                      alpha_e2=alpha_e2, 
                                      alpha_i=alpha_i)

# %%
plt.plot(sol_midpoint_t, np.abs(rho[Nx, :]))
plt.yscale("log")

# %% [markdown]
# # Conservation Laws
#
# ### mass conservation
#
# $$
# N^{s}(t) = \alpha^{s} \sum_{n=0}^{N_{v}-1} \int_{0}^{L} C_{n}^{s}(x, t)^{2}\mathrm{d}x =  \alpha^{s} \sum_{n=0}^{N_{v}-1} \int_{0}^{L} \sum_{k=-N_{x}}^{N_{x}} \sum_{m=-N_{x}}^{N_{x}} C_{n, k}^{s}(t) C_{n, m}^{s}(t) \exp(2\pi x i k/ L) \exp(2\pi x i m/ L) \mathrm{d}x
# = \alpha^{s} L \sum_{n=0}^{N_{v}-1} \sum_{k=-N_{x}}^{N_{x}} C_{n, k}^{s}(t) C_{n, -k}^{s}(t)
# $$

# %%
def mass(state):
    y = 0
    for nn in range(0, Nv):
        y += L * np.conjugate(state[nn, :]).T @ state[nn, :]
    return y

# %%
mass_midpoint = np.zeros(len(sol_midpoint_t))

for ii in range(0, len(sol_midpoint_t)):
    mass_midpoint[ii] = mass(state_e1_midpoint[:, :, ii]).real*alpha_e1\
                      + mass(state_e2_midpoint[:, :, ii]).real*alpha_e2\
                      + mass(state_i_midpoint[:, :, ii]).real*alpha_i

# %%
plt.plot(sol_midpoint_t, np.abs(mass_midpoint - mass_midpoint[0]))
plt.yscale("log")

# %% [markdown]
# ### momentum conservation

# %%
def term2(state):
    res = 0
    for nn in range(0, Nv):
        res += L * np.sqrt(nn/2)* np.conjugate(state[nn-1, :]).T @ state[nn, :] 
    return res

# %%
momentum_midpoint_e1 = np.zeros(len(sol_midpoint_t))
momentum_midpoint_e2 = np.zeros(len(sol_midpoint_t))
momentum_midpoint_i = np.zeros(len(sol_midpoint_t))
momentum_midpoint = np.zeros(len(sol_midpoint_t))

for ii in range(0, len(sol_midpoint_t)):
    momentum_midpoint_e1[ii] = m_e1*alpha_e1*(u_e1*mass(state_e1_midpoint[:, :, ii]) + alpha_e1*(2*term2(state_e1_midpoint[:, :, ii]))).real
    momentum_midpoint_e2[ii] = m_e2*alpha_e2*(u_e2*mass(state_e2_midpoint[:, :, ii]) + alpha_e2*(2*term2(state_e2_midpoint[:, :, ii]))).real
    momentum_midpoint_i[ii] = m_i*alpha_i*(u_i*mass(state_i_midpoint[:, :, ii]) + alpha_i*(2*term2(state_i_midpoint[:, :, ii]))).real
    momentum_midpoint[ii] = momentum_midpoint_e1[ii] + momentum_midpoint_e2[ii] + momentum_midpoint_i[ii]

# %%
plt.plot(sol_midpoint_t, np.abs(momentum_midpoint - momentum_midpoint[0]))
plt.yscale("log")

# %%
fig, ax = plt.subplots(ncols=3, figsize=(15, 3))
ax[1].plot(sol_midpoint_t, momentum_midpoint_e1-momentum_midpoint_e1[0], ls="--",  label="core momentum drift")
ax[1].plot(sol_midpoint_t, momentum_midpoint_e2-momentum_midpoint_e2[0], label="bump momentum drift")
ax[1].set_xlabel("t")
ax[1].set_xlim(0, T)
ax[1].legend()
ax[1].set_ylabel(r"$\mathcal{P}(t)-\mathcal{P}(t=0)$")

ax[0].plot(sol_midpoint_t[:20], momentum_midpoint_e1[:20]-momentum_midpoint_e1[0], ls="--",  label="core momentum drift")
ax[0].plot(sol_midpoint_t[:20], momentum_midpoint_e2[:20]-momentum_midpoint_e2[0], label="bump momentum drift")
ax[0].set_xlabel("t")
ax[0].legend()
ax[0].set_ylabel(r"$\mathcal{P}(t)-\mathcal{P}(t=0)$")

ax[2].plot(sol_midpoint_t, momentum_midpoint_e1-momentum_midpoint_e1[0]+  momentum_midpoint_e2-momentum_midpoint_e2[0], label="total momentum drift", c="black")
#ax[2].set_yscale("log")
ax[2].set_xlabel("t")
ax[2].set_ylabel(r"$\mathcal{P}(t)-\mathcal{P}(t=0)$")
plt.tight_layout()

# %%
#np.save("momentum_drift_VP_bump_on_tail_500.npy", momentum_midpoint)
